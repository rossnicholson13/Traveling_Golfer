# %%
import pandas as pd

# %%
final_db = pd.read_csv('final_db.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (19,20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
final_db.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1             Club Name_x                    Name  \
# 0           0             0  Andalusia Country Club  Andalusia Country Club
# 1           1             1  Andalusia Country Club  Andalusia Country Club
# 2           2             2  Andalusia Country Club  Andalusia Country Club
# 3           3             3  Andalusia Country Club  Andalusia Country Club
# 4           4             4  Andalusia Country Club  Andalusia Country Club
#
#       City_x State_x  Course ID             Google Places ID   Latitude  \
# 0  Andalusia      AL      11385  ChIJje5He1vpkYgRNPNFbM-xH3Q  31.316989
# 1  Andalusia      AL      11385  ChIJje5He1vpkYgRNPNFbM-xH3Q  31.316989
# 2  Andalusia      AL      11385  ChIJje5He1vpkYgRNPNFbM-xH3Q  31.316989
# 3  Andalusia      AL      11385  ChIJje5He1vpkYgRNPNFbM-xH3Q  31.316989
# 4  Andalusia      AL      11385  ChIJje5He1vpkYgRNPNFbM-xH3Q  31.316989
#
#    Longitude  ... Tee Name Par USGA Course Rating (18) Slope Rating (18)  \
# 0 -86.511974  ...     Blue  72                    69.7               123
# 1 -86.511974  ...    White  72                    68.9               120
# 2 -86.511974  ...     Gold  72                    65.9               111
# 3 -86.511974  ...  Gold -S  72                    64.9               106
# 4 -86.511974  ...      Red  72                    69.0               113
#
#   Front (9) Rating Front (9) Slope  Back (9) Rating  Back (9) Slope  \
# 0             34.2             121             35.5             125
# 1             33.8             117             35.1             122
# 2             32.4             110             33.5             112
# 3             32.2             104             32.7             108
# 4             34.2             112             34.8             114
#
#    Bogey Rating (18) Gender
# 0               92.5      M
# 1               91.1      M
# 2               86.5      M
# 3               84.6      M
# 4               95.6      F
#
# [5 rows x 25 columns]

# %%
final_db = final_db.rename(columns={'Tee Name': 'Tee', 'Slope Rating (18)': 'Slope_Rating', 'Bogey Rating (18)': 'Bogey_Rating', 'USGA_Rating': 'Usgarating'})

# %%
final_db.to_csv('final_db.csv')

# %%
final_db.tail(25)
# Out:
#        Unnamed: 0  Unnamed: 0.1                   Club Name_x  \
# 78590       80324         80324  Meridian Valley Country Club
# 78591       80325         80325  Meridian Valley Country Club
# 78592       80326         80326  Meridian Valley Country Club
# 78593       80327         80327  Meridian Valley Country Club
# 78594       80328         80328       Mill Creek Country Club
# 78595       80329         80329       Mill Creek Country Club
# 78596       80330         80330       Mill Creek Country Club
# 78597       80331         80331       Mill Creek Country Club
# 78598       80332         80332       Mill Creek Country Club
# 78599       80333         80333       Mill Creek Country Club
# 78600       80334         80334       Mill Creek Country Club
# 78601       80335         80335       Mill Creek Country Club
# 78602       80336         80336       Mill Creek Country Club
# 78603       80337         80337                Semiahmoo G&CC
# 78604       80338         80338                Semiahmoo G&CC
# 78605       80339         80339                Semiahmoo G&CC
# 78606       80340         80340                Semiahmoo G&CC
# 78607       80341         80341                Semiahmoo G&CC
# 78608       80342         80342                Semiahmoo G&CC
# 78609       80343         80343                Semiahmoo G&CC
# 78610       80344         80344                Semiahmoo G&CC
# 78611       80345         80345                Semiahmoo G&CC
# 78612       80346         80346                Semiahmoo G&CC
# 78613       80347         80347                Semiahmoo G&CC
# 78614       80348         80348                Semiahmoo G&CC
#
#                                Name      City_x State_x  Course ID  \
# 78590  Meridian Valley Country Club        Kent      WA       1407
# 78591  Meridian Valley Country Club        Kent      WA       1407
# 78592  Meridian Valley Country Club        Kent      WA       1407
# 78593  Meridian Valley Country Club        Kent      WA       1407
# 78594       Mill Creek Country Club  Mill Creek      WA       1417
# 78595       Mill Creek Country Club  Mill Creek      WA       1417
# 78596       Mill Creek Country Club  Mill Creek      WA       1417
# 78597       Mill Creek Country Club  Mill Creek      WA       1417
# 78598       Mill Creek Country Club  Mill Creek      WA       1417
# 78599       Mill Creek Country Club  Mill Creek      WA       1417
# 78600       Mill Creek Country Club  Mill Creek      WA       1417
# 78601       Mill Creek Country Club  Mill Creek      WA       1417
# 78602       Mill Creek Country Club  Mill Creek      WA       1417
# 78603                Semiahmoo G&CC      Blaine      WA       1587
# 78604                Semiahmoo G&CC      Blaine      WA       1587
# 78605                Semiahmoo G&CC      Blaine      WA       1587
# 78606                Semiahmoo G&CC      Blaine      WA       1587
# 78607                Semiahmoo G&CC      Blaine      WA       1587
# 78608                Semiahmoo G&CC      Blaine      WA       1587
# 78609                Semiahmoo G&CC      Blaine      WA       1587
# 78610                Semiahmoo G&CC      Blaine      WA       1587
# 78611                Semiahmoo G&CC      Blaine      WA       1587
# 78612                Semiahmoo G&CC      Blaine      WA       1587
# 78613                Semiahmoo G&CC      Blaine      WA       1587
# 78614                Semiahmoo G&CC      Blaine      WA       1587
#
#                   Google Places ID   Latitude   Longitude  ...           Tee  \
# 78590  ChIJoc4eqvZekFQRtxnzqGwI0zo  47.378411 -122.157178  ...          Gold
# 78591  ChIJoc4eqvZekFQRtxnzqGwI0zo  47.378411 -122.157178  ...      Gold/Red
# 78592  ChIJoc4eqvZekFQRtxnzqGwI0zo  47.378411 -122.157178  ...           Red
# 78593  ChIJoc4eqvZekFQRtxnzqGwI0zo  47.378411 -122.157178  ...     Green/Red
# 78594  ChIJ8_Ihj3EGkFQRc9dwgWv1zs8  47.867730 -122.201260  ...         Black
# 78595  ChIJ8_Ihj3EGkFQRc9dwgWv1zs8  47.867730 -122.201260  ...          Blue
# 78596  ChIJ8_Ihj3EGkFQRc9dwgWv1zs8  47.867730 -122.201260  ...        Member
# 78597  ChIJ8_Ihj3EGkFQRc9dwgWv1zs8  47.867730 -122.201260  ...         White
# 78598  ChIJ8_Ihj3EGkFQRc9dwgWv1zs8  47.867730 -122.201260  ...         Green
# 78599  ChIJ8_Ihj3EGkFQRc9dwgWv1zs8  47.867730 -122.201260  ...         White
# 78600  ChIJ8_Ihj3EGkFQRc9dwgWv1zs8  47.867730 -122.201260  ...         Green
# 78601  ChIJ8_Ihj3EGkFQRc9dwgWv1zs8  47.867730 -122.201260  ...        Member
# 78602  ChIJ8_Ihj3EGkFQRc9dwgWv1zs8  47.867730 -122.201260  ...           Red
# 78603  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...         Green
# 78604  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...          Blue
# 78605  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...    White/Blue
# 78606  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...         White
# 78607  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...  White/Yellow
# 78608  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...        Yellow
# 78609  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...        Orange
# 78610  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...         White
# 78611  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...  White/Yellow
# 78612  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...        Yellow
# 78613  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...           Red
# 78614  ChIJ5RH7Xs7AhVQREwc7zkv_8Jw  48.959339 -122.779913  ...        Orange
#
#       Par Usgarating Slope_Rating Front (9) Rating Front (9) Slope  \
# 78590  72       74.8          132             37.5             131
# 78591  72       74.1          130             37.2             129
# 78592  72       71.8          126             36.1             125
# 78593  70       66.8          116             33.4             111
# 78594  72       72.6          138             36.2             140
# 78595  72       71.9          135               36             138
# 78596  72       71.0          132             35.5             133
# 78597  72       70.4          131               35             131
# 78598  72       68.5          125               34             124
# 78599  72       75.8          141             38.2             143
# 78600  72       73.4          135             36.9             136
# 78601  72       72.1          132             35.8             131
# 78602  72       71.3          129             35.9             131
# 78603  72       74.0          138             37.1             137
# 78604  70       71.5          132             35.8             130
# 78605  70       70.5          132             35.3             127
# 78606  69       69.6          126             34.8             123
# 78607  69       68.0          123             33.9             119
# 78608  68       67.7          122             33.9             119
# 78609  68       61.5          102             30.6             102
# 78610  72       74.8          136             37.6             135
# 78611  72       73.1          132             36.6             131
# 78612  72       72.5          131             36.5             130
# 78613  71       71.3          125               36             126
# 78614  68       65.2          113             32.7             114
#
#        Back (9) Rating  Back (9) Slope  Bogey_Rating Gender
# 78590             37.3             132         105.8      F
# 78591             36.9             131         104.8      F
# 78592             35.7             126         101.4      F
# 78593             33.4             120          94.0      F
# 78594             36.4             135          98.1      M
# 78595             35.9             132          97.0      M
# 78596             35.5             131          95.6      M
# 78597             35.4             131          94.8      M
# 78598             34.5             126          91.7      M
# 78599             37.6             139         109.1      F
# 78600             36.5             134         105.2      F
# 78601             36.3             133         103.3      F
# 78602             35.4             126         101.6      F
# 78603             36.9             139          99.2      M
# 78604             35.7             134          95.7      M
# 78605             35.2             136          94.9      M
# 78606             34.8             128          92.9      M
# 78607             34.1             126          90.8      M
# 78608             33.8             124          90.3      M
# 78609             30.9             102          80.5      M
# 78610             37.2             136         106.7      F
# 78611             36.5             133         104.2      F
# 78612             36.0             131         103.2      F
# 78613             35.3             124         100.7      F
# 78614             32.5             112          91.8      F
#
# [25 rows x 25 columns]

# %%
names = []
lat = []
lng = []
info = []

for i in range(len(final_db)):
    if i == 0:
        names.append(final_db.iloc[i,3])
        lat.append(final_db.iloc[i,8])
        lng.append(final_db.iloc[i,9])
        
    if i <= len(final_db) - 2: 
        if final_db.iloc[i, 6] != final_db.iloc[i-1, 6]:
            names.append(final_db.iloc[i,3])
            lat.append(final_db.iloc[i,8])
            lng.append(final_db.iloc[i,9]) 
            
        if (final_db.iloc[i, 6] != final_db.iloc[i+1, 6]):
            temp_df = final_db.loc[final_db['Course ID'] == final_db.iloc[i,6]]
            course_info = {
                'Tee': list(temp_df['Tee']),
                'Par': list(temp_df['Par']),
                'USGA_Rating': list(temp_df['Usgarating']),
                'Slope_Rating': list(temp_df['Slope_Rating']),
                'Bogey_Rating': list(temp_df['Bogey_Rating']),
                'Gender': list(temp_df['Gender'])
            }
            info.append(course_info)
        
    if i == len(final_db) - 1:
        temp_df = final_db.loc[final_db['Course ID'] == final_db.iloc[i,6]]
        course_info = {
            'Tee': list(temp_df['Tee']),
            'Par': list(temp_df['Par']),
            'USGA_Rating': list(temp_df['Usgarating']),
            'Slope_Rating': list(temp_df['Slope_Rating']),
            'Bogey_Rating': list(temp_df['Bogey_Rating']),
            'Gender': list(temp_df['Gender'])
        }
        info.append(course_info)

# %%
len(names)
# Out:
# 10750

# %%
len(info)
# Out:
# 10748

# %%
course_db = pd.DataFrame({
    'Name': names,
    'Latitude': lat,
    'Longitude': lng,
    'Info': info
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-6c648586160c> in <module>
#       3     'Latitude': lat,
#       4     'Longitude': lng,
# ----> 5     'Info': info
#       6 })
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
names[-5:]
# Out:
# ['Meadowmeer Golf & Country Club',
#  'MeadowWood Golf Course',
#  'Meridian Valley Country Club',
#  'Mill Creek Country Club',
#  'Semiahmoo G&CC']

# %%
lat[-5:]
# Out:
# [47.666853, 47.651635, 47.378411, 47.86773, 48.959339]

# %%
lng[-5:]
# Out:
# [-122.53514399999999,
#  -117.08584499999999,
#  -122.157178,
#  -122.20126,
#  -122.779913]

# %%
info[-5:]
# Out:
# [{'Tee': ['Black',
#    'Blue',
#    'Blue/White',
#    'White',
#    'Red/White',
#    'Red',
#    'Gold',
#    'Blue',
#    'White',
#    'Red/White',
#    'Red',
#    'Red/Gold',
#    'Gold'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.9,
#    72.1,
#    71.7,
#    70.1,
#    69.5,
#    68.5,
#    65.7,
#    78.6,
#    75.8,
#    75.1,
#    73.5,
#    72.5,
#    70.9],
#   'Slope_Rating': [137,
#    134,
#    132,
#    127,
#    122,
#    116,
#    111,
#    142,
#    137,
#    136,
#    133,
#    129,
#    126],
#   'Bogey_Rating': [99.2,
#    97.0,
#    96.2,
#    93.6,
#    92.2,
#    90.0,
#    86.4,
#    112.0,
#    108.0,
#    107.1,
#    104.7,
#    103.0,
#    100.5],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['White/Blue',
#    'White/Red',
#    'Gold/Red',
#    'White/Blue',
#    'White/Red',
#    'Gold/Red'],
#   'Par': [69, 68, 60, 71, 70, 64],
#   'USGA_Rating': [67.5, 65.2, 61.3, 73.0, 70.2, 64.1],
#   'Slope_Rating': [119, 116, 104, 127, 121, 111],
#   'Bogey_Rating': [89.6, 86.7, 80.6, 102.9, 98.7, 90.1],
#   'Gender': ['M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'White', 'Gold', 'Red'],
#   'Par': [72, 72, 70, 70, 72, 72, 72],
#   'USGA_Rating': [72.5, 70.6, 67.5, 66.9, 76.8, 73.3, 72.8],
#   'Slope_Rating': [124, 123, 119, 117, 134, 128, 127],
#   'Bogey_Rating': [95.6, 93.5, 89.6, 88.6, 108.3, 103.4, 102.7],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue',
#    'Blue/White',
#    'White',
#    'Gold/White',
#    'Gold',
#    'Red',
#    'Green/Red',
#    'White',
#    'Gold/White',
#    'Gold',
#    'Gold/Red',
#    'Red',
#    'Green/Red'],
#   'Par': [72, 72, 72, 71, 70, 70, 64, 72, 72, 72, 72, 72, 70],
#   'USGA_Rating': [72.4,
#    71.2,
#    70.3,
#    69.4,
#    69.0,
#    66.8,
#    62.9,
#    76.4,
#    75.4,
#    74.8,
#    74.1,
#    71.8,
#    66.8],
#   'Slope_Rating': [134,
#    134,
#    134,
#    132,
#    130,
#    122,
#    110,
#    136,
#    133,
#    132,
#    130,
#    126,
#    116],
#   'Bogey_Rating': [97.2,
#    96.0,
#    95.2,
#    94.0,
#    93.2,
#    89.5,
#    83.3,
#    108.3,
#    106.8,
#    105.8,
#    104.8,
#    101.4,
#    94.0],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'Member',
#    'White',
#    'Green',
#    'White',
#    'Green',
#    'Member',
#    'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [72.6, 71.9, 71.0, 70.4, 68.5, 75.8, 73.4, 72.1, 71.3],
#   'Slope_Rating': [138, 135, 132, 131, 125, 141, 135, 132, 129],
#   'Bogey_Rating': [98.1, 97.0, 95.6, 94.8, 91.7, 109.1, 105.2, 103.3, 101.6],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']}]

# %%
info
# Out:
# [{'Tee': ['Blue', 'White', 'Gold', 'Gold -S', 'Red'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [69.7, 68.9, 65.9, 64.9, 69.0],
#   'Slope_Rating': [123, 120, 111, 106, 113],
#   'Bogey_Rating': [92.5, 91.1, 86.5, 84.6, 95.6],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red'],
#   'Par': [70, 70, 70, 70],
#   'USGA_Rating': [70.2, 68.4, 65.2, 69.5],
#   'Slope_Rating': [129, 128, 122, 118],
#   'Bogey_Rating': [94.1, 92.1, 87.8, 97.2],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'Orange', 'White', 'Gold', 'Green', 'Gold', 'Green'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [75.2, 72.7, 69.8, 67.5, 66.0, 72.4, 70.5],
#   'Slope_Rating': [140, 133, 131, 126, 122, 130, 126],
#   'Bogey_Rating': [101.1, 97.4, 94.1, 90.8, 88.7, 102.9, 100.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['I', 'II', 'III', 'IV', 'V', 'III', 'IV', 'V'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.2, 72.1, 69.6, 66.6, 63.8, 75.3, 72.0, 68.4],
#   'Slope_Rating': [125, 122, 120, 115, 108, 125, 118, 113],
#   'Bogey_Rating': [97.4, 94.6, 91.9, 87.9, 83.8, 104.7, 99.9, 95.0],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['I', 'II', 'III', 'IV', 'V', 'III', 'IV', 'V'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.3, 70.9, 67.3, 63.8, 60.5, 72.4, 68.1, 63.3],
#   'Slope_Rating': [132, 125, 118, 113, 105, 126, 117, 106],
#   'Bogey_Rating': [98.8, 94.0, 89.2, 84.8, 79.9, 102.1, 95.6, 88.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['I', 'II', 'III', 'IV', 'V', 'III', 'IV', 'V'],
#   'Par': [71, 71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [73.2, 69.7, 66.5, 62.7, 60.2, 71.7, 67.1, 62.8],
#   'Slope_Rating': [132, 124, 119, 109, 102, 123, 114, 104],
#   'Bogey_Rating': [97.7, 92.7, 88.5, 82.9, 79.0, 100.7, 93.9, 87.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['I', 'II', 'III', 'IV', 'V', 'III', 'IV', 'V'],
#   'Par': [71, 71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [72.1, 69.3, 66.8, 63.1, 60.6, 71.9, 67.4, 63.5],
#   'Slope_Rating': [128, 119, 115, 105, 99, 126, 117, 108],
#   'Bogey_Rating': [95.8, 91.5, 88.1, 82.4, 79.0, 101.6, 94.9, 89.0],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'Gold', 'Red'],
#   'Par': [72, 72, 72],
#   'USGA_Rating': [70.3, 66.4, 70.6],
#   'Slope_Rating': [120, 115, 126],
#   'Bogey_Rating': [92.5, 87.7, 100.3],
#   'Gender': ['M', 'M', 'F']},
#  {'Tee': ['Inferno', 'Blaze', 'Fire', 'Flame', 'Embers', 'Flame', 'Embers'],
#   'Par': [71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [73.7, 71.5, 68.2, 66.0, 63.3, 70.5, 67.2],
#   'Slope_Rating': [142, 138, 121, 117, 111, 127, 120],
#   'Bogey_Rating': [100.1, 97.0, 90.7, 87.7, 83.9, 100.4, 95.4],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red (Women)'],
#   'Par': [70, 70, 70, 0],
#   'USGA_Rating': [69.1, 67.0, 63.4, 67.1],
#   'Slope_Rating': [114, 109, 103, 114],
#   'Bogey_Rating': [90.2, 87.2, 82.4, 94.0],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Purple', 'Orange', 'White', 'Teal', 'Teal'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [74.4, 72.4, 69.0, 63.4, 67.7],
#   'Slope_Rating': [149, 147, 134, 122, 116],
#   'Bogey_Rating': [102.1, 99.6, 93.8, 86.0, 95.1],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Purple', 'Orange', 'White', 'Teal', 'Teal'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [74.4, 72.5, 69.0, 63.9, 68.4],
#   'Slope_Rating': [149, 146, 132, 122, 122],
#   'Bogey_Rating': [102.2, 99.6, 93.4, 86.5, 97.0],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Purple', 'Orange', 'White', 'Teal', 'Teal'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [74.4, 72.3, 68.3, 63.0, 66.8],
#   'Slope_Rating': [147, 143, 134, 120, 121],
#   'Bogey_Rating': [101.7, 98.8, 93.2, 85.2, 95.3],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Red'],
#   'Par': [72, 72, 71, 72, 72],
#   'USGA_Rating': [73.3, 70.8, 68.4, 64.2, 69.0],
#   'Slope_Rating': [136, 133, 118, 110, 120],
#   'Bogey_Rating': [98.5, 95.5, 90.2, 84.5, 97.2],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Green',
#    'Blue',
#    'White',
#    'Gold',
#    'Red',
#    'Purple',
#    'Gold',
#    'Red',
#    'Purple'],
#   'Par': [72, 72, 72, 72, 71, 72, 72, 72, 72],
#   'USGA_Rating': [74.8, 72.6, 69.9, 68.2, 64.3, 61.7, 73.9, 68.7, 64.5],
#   'Slope_Rating': [142, 139, 134, 128, 112, 105, 132, 119, 106],
#   'Bogey_Rating': [101.2, 98.3, 94.7, 91.8, 85.1, 81.2, 105.0, 96.7, 89.5],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black', 'Purple', 'Orange', 'White', 'Teal', 'White', 'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [78.5, 75.1, 71.7, 68.7, 64.7, 74.4, 68.4],
#   'Slope_Rating': [147, 142, 131, 128, 115, 137, 123],
#   'Bogey_Rating': [106.0, 101.5, 96.1, 92.5, 86.0, 106.6, 97.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Purple', 'Orange', 'White', 'Teal', 'White', 'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [76.9, 74.0, 71.4, 69.4, 66.1, 74.3, 70.4],
#   'Slope_Rating': [149, 143, 139, 131, 117, 133, 121],
#   'Bogey_Rating': [104.5, 100.6, 97.2, 93.7, 87.8, 105.5, 98.9],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Purple', 'Orange', 'White', 'Teal', 'White', 'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [77.4, 74.1, 70.9, 68.1, 64.7, 73.6, 69.6],
#   'Slope_Rating': [132, 125, 126, 121, 110, 123, 116],
#   'Bogey_Rating': [101.9, 97.4, 94.3, 90.5, 85.0, 102.6, 96.8],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Red'],
#   'Par': [71, 71, 71, 71, 72],
#   'USGA_Rating': [71.2, 68.9, 63.8, 63.0, 67.8],
#   'Slope_Rating': [126, 121, 109, 107, 117],
#   'Bogey_Rating': [94.6, 91.4, 84.0, 82.8, 95.4],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'Combo', 'Gold', 'Gold', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.3, 71.8, 70.0, 68.8, 67.5, 72.6, 70.4],
#   'Slope_Rating': [141, 140, 134, 128, 123, 129, 125],
#   'Bogey_Rating': [99.4, 97.7, 94.8, 92.6, 90.3, 103.0, 99.8],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Yellow', 'Blue', 'White', 'Red'],
#   'Par': [71, 71, 71, 71],
#   'USGA_Rating': [71.7, 69.1, 66.5, 67.9],
#   'Slope_Rating': [125, 121, 109, 107],
#   'Bogey_Rating': [94.8, 91.5, 86.7, 93.2],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['I', 'II', 'III', 'IV', 'V', 'IV Women', 'V Women'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.0, 72.1, 69.3, 66.4, 63.6, 70.5, 66.6],
#   'Slope_Rating': [140, 136, 129, 116, 110, 115, 108],
#   'Bogey_Rating': [100.0, 97.3, 93.2, 87.9, 84.0, 97.7, 92.0],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Yellow', 'Yellow', 'Red'],
#   'Par': [71, 71, 71, 71, 71],
#   'USGA_Rating': [71.4, 68.9, 66.6, 72.2, 70.5],
#   'Slope_Rating': [114, 114, 110, 119, 113],
#   'Bogey_Rating': [92.5, 90.1, 86.9, 100.1, 97.2],
#   'Gender': ['M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'Yellow', 'White', 'Forward'],
#   'Par': [72, 72, 72, 72],
#   'USGA_Rating': [70.2, 68.3, 66.7, 70.2],
#   'Slope_Rating': [121, 116, 111, 116],
#   'Bogey_Rating': [92.5, 89.8, 87.3, 97.4],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Nelson', 'Blue', 'White', 'Gold', "Women's Red"],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [73.7, 72.3, 71.0, 68.6, 71.3],
#   'Slope_Rating': [137, 134, 130, 122, 127],
#   'Bogey_Rating': [99.1, 97.1, 95.2, 91.2, 101.1],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red Long', 'Red', 'Red Long', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [70.8, 69.1, 67.4, 65.7, 64.0, 70.4, 68.3],
#   'Slope_Rating': [133, 124, 119, 115, 113, 119, 116],
#   'Bogey_Rating': [95.5, 92.0, 89.5, 87.1, 84.9, 98.5, 95.5],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'RED'],
#   'Par': [72, 72, 72, 72],
#   'USGA_Rating': [71.2, 69.3, 64.4, 66.8],
#   'Slope_Rating': [122, 123, 113, 117],
#   'Bogey_Rating': [93.9, 92.0, 85.3, 94.3],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Silver', 'Silver'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [72.6, 70.9, 67.7, 63.1, 67.3],
#   'Slope_Rating': [136, 130, 125, 115, 119],
#   'Bogey_Rating': [97.7, 95.0, 90.9, 84.4, 95.2],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Silver', 'White', 'Gold', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [72.0, 69.1, 67.0, 64.6, 74.3, 72.0, 68.3],
#   'Slope_Rating': [134, 129, 124, 119, 137, 133, 125],
#   'Bogey_Rating': [96.8, 93.1, 89.9, 86.6, 106.5, 103.2, 97.7],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black', 'Gold', 'Silver', 'Green', 'Red'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [72.9, 71.3, 68.3, 65.4, 69.7],
#   'Slope_Rating': [125, 122, 114, 107, 117],
#   'Bogey_Rating': [96.0, 93.9, 89.5, 85.3, 97.3],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['White', 'Gold', 'Red'],
#   'Par': [70, 70, 70],
#   'USGA_Rating': [69.8, 66.0, 66.1],
#   'Slope_Rating': [126, 114, 108],
#   'Bogey_Rating': [93.1, 87.2, 91.6],
#   'Gender': ['M', 'M', 'F']},
#  {'Tee': ['Gold', 'Blue', 'White', 'Red', 'White', 'Red'],
#   'Par': [70, 70, 70, 70, 70, 70],
#   'USGA_Rating': [71.6, 69.7, 66.5, 63.2, 72.3, 67.8],
#   'Slope_Rating': [125, 125, 117, 110, 128, 116],
#   'Bogey_Rating': [94.8, 92.9, 88.2, 83.6, 102.3, 95.2],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Silver', 'Gold', 'Short', 'Red'],
#   'Par': [72, 72, 72, 72, 0, 72],
#   'USGA_Rating': [70.4, 69.0, 66.3, 64.7, 68.6, 67.7],
#   'Slope_Rating': [121, 120, 104, 100, 112, 114],
#   'Bogey_Rating': [92.8, 91.3, 85.7, 83.3, 95.0, 94.5],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Red', 'Purple'],
#   'Par': [71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [70.5, 68.9, 65.1, 62.5, 66.9, 63.8],
#   'Slope_Rating': [126, 119, 109, 102, 106, 103],
#   'Bogey_Rating': [93.8, 91.0, 85.3, 81.5, 91.9, 88.0],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Longhorn',
#    'Copperhead',
#    'Whitetail',
#    'Bobcat',
#    'Quail',
#    'Bobcat',
#    'Quail'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [75.9, 73.1, 70.3, 67.4, 64.3, 72.7, 68.9],
#   'Slope_Rating': [142, 136, 131, 123, 116, 130, 122],
#   'Bogey_Rating': [102.3, 98.3, 94.6, 90.2, 85.8, 103.2, 97.7],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'Gold', 'Red'],
#   'Par': [71, 71, 71, 71, 71],
#   'USGA_Rating': [71.3, 70.2, 69.1, 66.4, 70.0],
#   'Slope_Rating': [123, 119, 114, 108, 115],
#   'Bogey_Rating': [94.0, 92.3, 90.2, 86.4, 97.0],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Gold', 'Red'],
#   'Par': [71, 71, 71, 71, 72, 72],
#   'USGA_Rating': [69.5, 68.5, 65.7, 64.2, 70.8, 68.8],
#   'Slope_Rating': [111, 113, 109, 102, 117, 114],
#   'Bogey_Rating': [90.1, 89.4, 85.8, 83.2, 98.4, 95.7],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Gold',
#    'Blue',
#    'White',
#    'Green',
#    'Red',
#    'Blue',
#    'White',
#    'Green',
#    'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [72.3, 69.5, 67.2, 65.7, 63.6, 75.1, 72.3, 70.9, 68.2],
#   'Slope_Rating': [130, 128, 123, 121, 116, 129, 123, 120, 114],
#   'Bogey_Rating': [96.3, 93.2, 90.0, 88.1, 85.1, 105.5, 101.2, 99.1, 95.0],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'Purple', 'Red/White', 'Red', 'Purple'],
#   'Par': [71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [71.5, 69.3, 66.4, 61.1, 69.9, 68.4, 63.5],
#   'Slope_Rating': [131, 126, 117, 103, 119, 116, 105],
#   'Bogey_Rating': [95.7, 92.7, 88.1, 80.0, 97.9, 95.8, 88.3],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'Purple', 'White', 'Red', 'Purple'],
#   'Par': [70, 70, 70, 70, 70, 70, 70],
#   'USGA_Rating': [68.4, 66.8, 63.4, 60.6, 69.2, 66.8, 63.0],
#   'Slope_Rating': [124, 118, 109, 97, 115, 110, 99],
#   'Bogey_Rating': [91.4, 88.8, 83.6, 78.5, 96.4, 92.8, 86.4],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'Blue/White',
#    'White',
#    'Purple',
#    'White/Red',
#    'Red',
#    'Purple'],
#   'Par': [70, 70, 70, 70, 70, 70, 70, 70],
#   'USGA_Rating': [70.1, 68.0, 66.9, 65.4, 61.1, 69.6, 68.4, 64.0],
#   'Slope_Rating': [126, 118, 115, 110, 99, 113, 111, 104],
#   'Bogey_Rating': [93.4, 89.9, 88.2, 85.7, 79.5, 96.3, 94.5, 88.6],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'Gold', 'Purple', 'Red', 'Purple'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.2, 70.6, 68.4, 65.8, 61.8, 70.3, 64.5],
#   'Slope_Rating': [132, 126, 118, 111, 105, 117, 110],
#   'Bogey_Rating': [97.6, 94.0, 90.2, 86.4, 81.2, 97.8, 90.4],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Purple', 'Orange', 'White', 'Teal', 'Orange', 'White', 'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.9, 70.6, 68.2, 63.0, 77.5, 74.3, 67.8],
#   'Slope_Rating': [132, 122, 115, 105, 139, 128, 119],
#   'Bogey_Rating': [98.4, 93.2, 89.5, 82.5, 110.2, 104.5, 95.9],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Purple', 'Orange', 'White', 'Teal', 'Orange', 'White', 'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [75.2, 71.5, 69.1, 63.7, 78.1, 74.7, 68.4],
#   'Slope_Rating': [142, 127, 123, 110, 143, 138, 112],
#   'Bogey_Rating': [101.6, 95.1, 91.9, 84.2, 111.8, 107.1, 94.7],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue/Orange', 'White/Blue', 'Gold', 'Red'],
#   'Par': [70, 70, 70, 70],
#   'USGA_Rating': [68.2, 67.0, 63.6, 67.2],
#   'Slope_Rating': [119, 117, 110, 121],
#   'Bogey_Rating': [90.3, 88.7, 84.0, 95.8],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Black', 'Gold', 'Blue', 'White', 'Orange'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [72.7, 70.9, 69.1, 67.7, 65.4],
#   'Slope_Rating': [133, 130, 122, 118, 107],
#   'Bogey_Rating': [97.6, 95.0, 91.8, 89.6, 85.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M']},
#  {'Tee': ['Black', 'Purple', 'Orange', 'White', 'Teal', 'White', 'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [75.0, 72.6, 70.2, 67.1, 63.9, 72.2, 68.5],
#   'Slope_Rating': [144, 138, 134, 122, 116, 126, 119],
#   'Bogey_Rating': [101.7, 98.2, 95.0, 89.7, 85.4, 101.9, 96.5],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Purple', 'Orange', 'White', 'Teal', 'White', 'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.7, 72.3, 69.9, 67.1, 63.5, 72.7, 68.5],
#   'Slope_Rating': [139, 133, 129, 120, 113, 124, 116],
#   'Bogey_Rating': [100.4, 97.1, 93.8, 89.3, 84.4, 102.0, 95.7],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Purple', 'Orange', 'White', 'Teal', 'White', 'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [75.5, 72.9, 70.5, 67.4, 63.6, 73.1, 68.6],
#   'Slope_Rating': [144, 138, 133, 124, 116, 130, 121],
#   'Bogey_Rating': [102.1, 98.5, 95.2, 90.4, 85.2, 103.7, 97.0],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'White', 'Red'],
#   'Par': [72, 72, 72],
#   'USGA_Rating': [68.4, 67.8, 70.6],
#   'Slope_Rating': [112, 113, 113],
#   'Bogey_Rating': [89.2, 88.8, 97.2],
#   'Gender': ['M', 'M', 'F']},
#  {'Tee': ['Gold',
#    'Gold/Blue',
#    'Blue',
#    'Blue/White',
#    'White',
#    'Green',
#    'White',
#    'Green'],
#   'Par': [70, 70, 70, 70, 70, 70, 70, 70],
#   'USGA_Rating': [71.5, 69.3, 68.7, 67.3, 66.4, 64.4, 71.4, 69.6],
#   'Slope_Rating': [128, 123, 120, 115, 114, 111, 132, 121],
#   'Bogey_Rating': [95.3, 92.1, 91.0, 88.7, 87.6, 85.0, 102.5, 98.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Gold', 'Red'],
#   'Par': [70, 70, 68, 70, 70, 70],
#   'USGA_Rating': [70.0, 67.8, 63.8, 61.4, 68.3, 64.5],
#   'Slope_Rating': [120, 120, 102, 99, 117, 104],
#   'Bogey_Rating': [92.3, 90.0, 82.8, 79.7, 95.7, 88.9],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Red', 'Purple', 'White/Blue'],
#   'Par': [0, 0, 0],
#   'USGA_Rating': [71.2, 70.2, 68.9],
#   'Slope_Rating': [129, 127, 125],
#   'Bogey_Rating': [94.6, 94.6, 94.6],
#   'Gender': ['M', 'M', 'M']},
#  {'Tee': ['Blue', 'White', 'White/Green', 'Green', 'Red', 'Red', 'Gold'],
#   'Par': [71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [70.0, 68.8, 67.4, 66.1, 64.2, 68.3, 67.5],
#   'Slope_Rating': [115, 113, 106, 104, 100, 110, 108],
#   'Bogey_Rating': [91.3, 89.7, 87.1, 85.3, 82.7, 94.2, 93.0],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Member', 'Senior', "Women's"],
#   'Par': [72, 72, 72],
#   'USGA_Rating': [69.3, 65.5, 69.7],
#   'Slope_Rating': [125, 108, 117],
#   'Bogey_Rating': [92.4, 85.4, 97.2],
#   'Gender': ['M', 'M', 'F']},
#  {'Tee': ['Purple', 'Orange', 'White', 'Teal', 'Teal', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.4, 71.8, 69.4, 65.7, 70.3, 66.5],
#   'Slope_Rating': [131, 126, 123, 110, 118, 109],
#   'Bogey_Rating': [98.7, 95.2, 92.2, 86.1, 98.2, 92.2],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Purple',
#    'Orange',
#    'White',
#    'Teal',
#    'Red',
#    'Orange',
#    'White',
#    'Teal',
#    'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.7, 71.2, 68.5, 64.5, 61.6, 77.8, 74.8, 70.2, 66.2],
#   'Slope_Rating': [136, 130, 126, 112, 105, 132, 125, 115, 107],
#   'Bogey_Rating': [98.8, 95.3, 91.8, 85.3, 81.1, 108.8, 104.2, 97.3, 91.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red'],
#   'Par': [72, 72, 72, 72],
#   'USGA_Rating': [71.0, 68.2, 66.0, 69.1],
#   'Slope_Rating': [130, 124, 112, 115],
#   'Bogey_Rating': [95.2, 91.1, 86.7, 96.3],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['I', 'II', 'III', 'IV', 'III', 'IV'],
#   'Par': [72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.4, 70.3, 67.9, 63.5, 73.1, 68.7],
#   'Slope_Rating': [139, 136, 125, 113, 134, 124],
#   'Bogey_Rating': [99.1, 95.5, 91.1, 84.4, 104.6, 97.9],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Silver', 'Gold', 'Red'],
#   'Par': [71, 71, 71, 71, 71],
#   'USGA_Rating': [71.3, 69.5, 67.3, 65.7, 68.5],
#   'Slope_Rating': [126, 125, 122, 114, 117],
#   'Bogey_Rating': [94.7, 92.6, 89.8, 86.8, 96.0],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Gold',
#    'Blue',
#    'Blue/White',
#    'White',
#    'Green',
#    'Red',
#    'White',
#    'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [73.4, 70.9, 70.1, 68.9, 65.8, 65.0, 74.0, 69.2],
#   'Slope_Rating': [137, 130, 125, 122, 115, 113, 132, 123],
#   'Bogey_Rating': [98.7, 95.0, 93.2, 91.5, 87.1, 85.9, 105.0, 98.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Crimson', 'Black', 'Blue', 'White', 'Gold', 'Gold'],
#   'Par': [72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [76.6, 74.6, 72.0, 69.1, 64.7, 69.8],
#   'Slope_Rating': [138, 134, 132, 129, 117, 128],
#   'Bogey_Rating': [102.1, 99.5, 96.6, 93.0, 86.3, 100.0],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'Gold 1', 'Gold 2', 'Green', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [74.6, 71.8, 69.2, 65.8, 65.2, 72.1, 69.4],
#   'Slope_Rating': [134, 131, 127, 110, 108, 127, 122],
#   'Bogey_Rating': [99.5, 96.1, 92.8, 86.2, 85.3, 102.1, 98.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Yellow', 'Red', 'Red'],
#   'Par': [71, 71, 71, 71, 71],
#   'USGA_Rating': [70.3, 68.8, 65.4, 63.4, 68.5],
#   'Slope_Rating': [125, 122, 106, 101, 117],
#   'Bogey_Rating': [93.4, 91.5, 85.1, 82.1, 95.9],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue',
#    'White',
#    'Gold',
#    'Gold/Green',
#    'Red',
#    'White',
#    'Gold',
#    'Gold/Green',
#    'Red'],
#   'Par': [71, 71, 68, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [70.4, 68.5, 66.3, 64.9, 64.3, 73.6, 70.8, 69.2, 68.4],
#   'Slope_Rating': [130, 128, 119, 117, 115, 133, 127, 124, 122],
#   'Bogey_Rating': [94.4, 92.2, 88.4, 86.5, 85.6, 104.9, 100.6, 98.3, 97.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Green', 'Red', 'Gold', 'Green', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [70.0, 68.8, 65.4, 64.5, 62.2, 70.4, 69.9, 67.0],
#   'Slope_Rating': [123, 120, 110, 109, 102, 119, 119, 112],
#   'Bogey_Rating': [92.7, 91.0, 85.8, 84.6, 81.2, 98.4, 97.8, 93.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['#1',
#    '#2',
#    '#3',
#    'Honours',
#    '#4',
#    "Women's #3",
#    'Honours',
#    "Women's #4"],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [72.4, 69.7, 67.9, 66.7, 63.0, 73.1, 71.7, 67.9],
#   'Slope_Rating': [127, 124, 118, 115, 101, 127, 124, 113],
#   'Bogey_Rating': [96.0, 92.6, 89.7, 88.0, 81.7, 103.0, 100.8, 94.4],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'White',
#    'Old Pro Tees',
#    'Gold',
#    'Silver',
#    'Green',
#    'Gold',
#    'Red',
#    'Green'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.7, 71.8, 70.2, 68.2, 67.6, 65.1, 60.9, 72.1, 69.0, 63.3],
#   'Slope_Rating': [137, 134, 128, 124, 116, 113, 103, 129, 117, 104],
#   'Bogey_Rating': [99.2,
#    96.6,
#    93.9,
#    91.2,
#    89.2,
#    86.0,
#    80.1,
#    102.5,
#    96.5,
#    87.7],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red'],
#   'Par': [0, 0, 0, 0],
#   'USGA_Rating': [70.5, 69.4, 65.6, 69.8],
#   'Slope_Rating': [123, 121, 115, 120],
#   'Bogey_Rating': [93.2, 91.8, 87.0, 97.9],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Black',
#    'Purple',
#    'Orange',
#    'White',
#    'Silver',
#    'Teal',
#    'White',
#    'Silver',
#    'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [76.2, 74.5, 71.8, 69.4, 67.0, 64.1, 76.3, 73.1, 68.8],
#   'Slope_Rating': [147, 143, 137, 131, 126, 109, 149, 142, 122],
#   'Bogey_Rating': [103.5, 101.1, 97.3, 93.7, 90.4, 84.4, 111.3, 106.5, 97.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Purple',
#    'Orange',
#    'White',
#    'Silver',
#    'Teal',
#    'White',
#    'Silver',
#    'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [76.7, 74.4, 71.8, 69.3, 67.2, 64.5, 75.5, 72.9, 69.4],
#   'Slope_Rating': [142, 137, 128, 126, 122, 111, 145, 140, 123],
#   'Bogey_Rating': [103.0, 99.8, 95.6, 92.6, 89.8, 85.0, 109.6, 105.7, 98.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Purple',
#    'Orange',
#    'White',
#    'Silver',
#    'Teal',
#    'White',
#    'Silver',
#    'Teal'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [75.9, 73.5, 71.8, 69.6, 67.1, 64.6, 75.8, 72.8, 68.4],
#   'Slope_Rating': [146, 140, 137, 131, 125, 107, 146, 140, 119],
#   'Bogey_Rating': [102.9, 99.5, 97.3, 94.0, 90.3, 84.4, 110.1, 105.6, 96.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Red'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [72.3, 71.1, 67.6, 65.4, 70.5],
#   'Slope_Rating': [128, 125, 115, 111, 120],
#   'Bogey_Rating': [96.0, 94.2, 89.0, 86.0, 98.6],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Red'],
#   'Par': [71, 71, 71, 71, 71],
#   'USGA_Rating': [71.0, 69.9, 66.4, 64.4, 69.0],
#   'Slope_Rating': [124, 122, 115, 110, 116],
#   'Bogey_Rating': [94.0, 92.5, 87.7, 84.8, 96.2],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Red'],
#   'Par': [71, 71, 71, 71, 71],
#   'USGA_Rating': [71.1, 70.0, 66.6, 63.6, 68.1],
#   'Slope_Rating': [126, 122, 114, 108, 116],
#   'Bogey_Rating': [94.4, 92.7, 87.7, 83.6, 95.4],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'Orange', 'White', 'Yellow', 'Yellow', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.8, 71.0, 68.3, 65.9, 70.6, 66.8],
#   'Slope_Rating': [124, 123, 114, 100, 119, 111],
#   'Bogey_Rating': [96.8, 93.7, 89.4, 84.5, 98.7, 92.9],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Gold',
#    'Blue',
#    'Green',
#    'White',
#    'Red',
#    'Forward',
#    'Green',
#    'White',
#    'Red',
#    'Forward'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.8, 71.1, 70.0, 67.9, 65.1, 62.9, 75.2, 72.5, 69.3, 66.2],
#   'Slope_Rating': [125, 119, 120, 116, 110, 104, 132, 127, 119, 112],
#   'Bogey_Rating': [96.9,
#    93.2,
#    92.3,
#    89.4,
#    85.5,
#    82.3,
#    106.3,
#    102.3,
#    97.3,
#    92.6],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Green', 'Blue', 'White', 'Gold', 'Red'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [73.3, 72.0, 69.5, 65.1, 68.2],
#   'Slope_Rating': [140, 139, 134, 116, 118],
#   'Bogey_Rating': [99.3, 97.9, 94.3, 86.6, 96.1],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Blue', 'White', 'Gold', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [70.9, 68.8, 66.2, 63.2, 76.6, 74.3, 71.3, 67.6],
#   'Slope_Rating': [128, 127, 121, 114, 139, 135, 128, 121],
#   'Bogey_Rating': [94.7, 92.4, 88.6, 84.3, 109.4, 106.0, 101.5, 96.1],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue',
#    'White',
#    'Gold',
#    'Red',
#    'Green',
#    'White',
#    'Gold',
#    'Red',
#    'Green'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [72.4, 70.2, 67.0, 64.8, 60.5, 76.2, 72.5, 69.8, 61.6],
#   'Slope_Rating': [123, 123, 114, 115, 98, 130, 124, 118, 100],
#   'Bogey_Rating': [95.1, 92.9, 88.1, 86.2, 78.7, 106.9, 101.6, 97.5, 85.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue',
#    'White',
#    'Gold',
#    'Red',
#    'Green',
#    'White',
#    'Gold',
#    'Red',
#    'Green'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.1, 70.3, 67.9, 64.6, 60.8, 77.5, 73.2, 68.9, 61.7],
#   'Slope_Rating': [131, 119, 114, 117, 96, 134, 126, 116, 102],
#   'Bogey_Rating': [97.4, 92.4, 89.1, 86.4, 78.6, 109.0, 102.8, 96.2, 85.8],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red'],
#   'Par': [72, 72, 72, 72],
#   'USGA_Rating': [70.0, 68.6, 64.1, 68.9],
#   'Slope_Rating': [120, 117, 102, 120],
#   'Bogey_Rating': [92.3, 90.4, 83.0, 97.1],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White', 'Red', 'RED'],
#   'Par': [72, 72, 72, 72],
#   'USGA_Rating': [69.6, 67.7, 63.9, 68.9],
#   'Slope_Rating': [121, 113, 100, 110],
#   'Bogey_Rating': [92.1, 88.7, 82.4, 94.7],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Gold', 'Blue', 'White', 'Green', 'Red', 'White', 'Green', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.6, 70.7, 68.6, 66.1, 63.8, 73.7, 70.8, 68.2],
#   'Slope_Rating': [126, 124, 117, 111, 106, 122, 117, 112],
#   'Bogey_Rating': [96.9, 93.7, 90.3, 86.6, 83.5, 102.5, 98.3, 94.5],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Gold', 'Blue', 'White', 'Green', 'Red', 'White', 'Green', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.8, 71.8, 69.3, 66.5, 64.5, 74.5, 71.1, 68.7],
#   'Slope_Rating': [141, 133, 121, 116, 112, 132, 124, 119],
#   'Bogey_Rating': [100.9, 96.4, 91.8, 88.0, 85.3, 105.5, 100.3, 96.7],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Gold', 'Blue', 'White', 'Green', 'Red', 'White', 'Green', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [75.2, 72.5, 69.3, 67.4, 65.1, 74.5, 72.5, 69.5],
#   'Slope_Rating': [137, 132, 121, 120, 115, 130, 125, 119],
#   'Bogey_Rating': [100.6, 96.9, 91.8, 89.6, 86.4, 105.0, 101.9, 97.4],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'Black', 'White', 'Gold', 'Red', 'White', 'Gold', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [73.3, 71.5, 70.2, 67.4, 63.5, 75.5, 72.2, 67.9],
#   'Slope_Rating': [137, 133, 132, 126, 114, 133, 126, 121],
#   'Bogey_Rating': [98.8, 96.2, 94.8, 90.7, 84.6, 106.9, 101.9, 96.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Silver'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [69.1, 68.0, 63.1, 67.6, 64.8],
#   'Slope_Rating': [125, 123, 104, 121, 111],
#   'Bogey_Rating': [92.3, 90.8, 82.3, 96.0, 91.0],
#   'Gender': ['M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'Gold', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [68.7, 66.7, 63.1, 62.8, 67.6, 67.2],
#   'Slope_Rating': [123, 118, 108, 107, 115, 114],
#   'Bogey_Rating': [91.4, 88.6, 83.2, 82.7, 94.7, 94.0],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue',
#    'White',
#    'Green',
#    'Gold',
#    'Red',
#    'Red/Silver',
#    'Gold',
#    'Red',
#    'Silver'],
#   'Par': [72, 72, 72, 72, 0, 0, 0, 72, 72],
#   'USGA_Rating': [74.8, 72.1, 70.7, 69.3, 67.2, 63.5, 75.0, 72.5, 66.3],
#   'Slope_Rating': [134, 128, 123, 119, 114, 105, 129, 124, 108],
#   'Bogey_Rating': [99.6, 95.8, 93.6, 91.3, 79.4, 74.5, 97.2, 101.8, 91.6],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Gold', 'Blue', 'White', 'Red', 'Red'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [72.8, 70.6, 67.0, 63.5, 67.5],
#   'Slope_Rating': [133, 130, 121, 112, 118],
#   'Bogey_Rating': [97.5, 94.8, 89.4, 84.3, 95.3],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Gold', 'Blue', 'White', 'Silver', 'Red/White', 'Red/Red'],
#   'Par': [71, 71, 70, 69, 71, 71],
#   'USGA_Rating': [69.8, 68.8, 65.9, 65.2, 69.8, 68.6],
#   'Slope_Rating': [131, 128, 115, 114, 118, 117],
#   'Bogey_Rating': [94.0, 92.6, 87.3, 86.3, 97.6, 96.1],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['MENS MIDDLE', 'WOMENS FORWARD'],
#   'Par': [68, 70],
#   'USGA_Rating': [69.2, 70.8],
#   'Slope_Rating': [128, 132],
#   'Bogey_Rating': [93.0, 101.9],
#   'Gender': ['M', 'F']},
#  {'Tee': ['Men Blue temp',
#    'Men White-Blue temp',
#    'Men White temp',
#    'Men Gold-Green temp',
#    'Men Red-Wild Rose temp',
#    'Women Red-Wild Rose temp'],
#   'Par': [72, 72, 72, 67, 65, 70],
#   'USGA_Rating': [70.8, 69.9, 69.0, 65.2, 63.3, 67.8],
#   'Slope_Rating': [128, 126, 124, 114, 110, 120],
#   'Bogey_Rating': [94.6, 93.3, 92.0, 86.4, 83.6, 96.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Blue(men)', 'Combo (White-Blue)', 'White(Men)', 'Red(Forward)18'],
#   'Par': [74, 74, 74, 74],
#   'USGA_Rating': [69.5, 69.2, 69.0, 69.6],
#   'Slope_Rating': [127, 126, 125, 121],
#   'Bogey_Rating': [93.1, 92.7, 92.3, 98.1],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['BLUE', 'WHITE', 'Gold', 'RED'],
#   'Par': [72, 72, 68, 72],
#   'USGA_Rating': [73.0, 70.7, 66.9, 71.3],
#   'Slope_Rating': [132, 129, 112, 124],
#   'Bogey_Rating': [97.5, 94.7, 87.7, 100.5],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Blue', 'White & Blue', 'White', 'Red'],
#   'Par': [72, 72, 72, 72],
#   'USGA_Rating': [72.8, 71.8, 70.8, 68.0],
#   'Slope_Rating': [115, 113, 110, 108],
#   'Bogey_Rating': [94.2, 92.7, 91.2, 93.4],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Back (Blue)',
#    'Middle (White)',
#    'Forward (Gold)',
#    'Womens Gold',
#    'Forward (Red)'],
#   'Par': [73, 73, 73, 73, 73],
#   'USGA_Rating': [75.5, 73.7, 66.6, 73.3, 69.7],
#   'Slope_Rating': [155, 151, 134, 129, 123],
#   'Bogey_Rating': [103.8, 101.7, 92.0, 108.0, 98.7],
#   'Gender': ['M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'Gold', 'Red'],
#   'Par': [72, 72, 72, 72, 72],
#   'USGA_Rating': [75.7, 73.3, 70.6, 67.3, 72.0],
#   'Slope_Rating': [141, 139, 133, 126, 134],
#   'Bogey_Rating': [101.9, 99.1, 95.2, 90.7, 103.5],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Men White',
#    'Men Gold',
#    'Men Red',
#    'Women White',
#    'Women Gold',
#    'Women Red'],
#   'Par': [72, 72, 71, 78, 71, 72],
#   'USGA_Rating': [70.6, 66.6, 65.2, 76.8, 72.4, 70.4],
#   'Slope_Rating': [119, 112, 108, 135, 125, 121],
#   'Bogey_Rating': [92.6, 87.3, 85.2, 108.6, 101.9, 99.0],
#   'Gender': ['M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue',
#    'Blue (copy)',
#    'White',
#    'Gold',
#    'Red (men)',
#    'Red (women)',
#    'Green (women)'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.2, 72.5, 70.3, 69.7, 67.4, 72.4, 66.7],
#   'Slope_Rating': [117, 126, 116, 108, 105, 121, 109],
#   'Bogey_Rating': [94.8, 95.9, 91.8, 89.7, 87.0, 100.9, 92.4],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White/Blue', 'White', 'Yellow', 'Red/Yellow', 'Red'],
#   'Par': [70, 70, 70, 70, 70, 70],
#   'USGA_Rating': [69.1, 67.2, 65.3, 69.9, 68.6, 67.3],
#   'Slope_Rating': [132, 130, 128, 120, 119, 117],
#   'Bogey_Rating': [93.6, 91.3, 89.0, 98.1, 96.5, 94.9],
#   'Gender': ['M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Championship', 'Regular', 'Futures', 'Regular', 'Forward'],
#   'Par': [72, 72, 56, 72, 72],
#   'USGA_Rating': [72.2, 69.0, 53.0, 75.3, 71.3],
#   'Slope_Rating': [122, 118, 74, 132, 125],
#   'Bogey_Rating': [94.9, 90.9, 66.8, 106.3, 100.7],
#   'Gender': ['M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'White', 'Gold', 'Teal', 'White', 'Gold', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [71.0, 68.4, 65.7, 63.7, 74.0, 71.5, 68.9],
#   'Slope_Rating': [121, 116, 110, 105, 134, 123, 118],
#   'Bogey_Rating': [93.3, 89.9, 86.0, 83.2, 105.5, 100.4, 96.7],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Silver',
#    'Gold',
#    'Red',
#    'Gold',
#    'championship format 2018',
#    'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [72.8, 70.1, 68.2, 65.7, 74.5, 72.0, 71.4],
#   'Slope_Rating': [128, 124, 114, 109, 127, 121, 121],
#   'Bogey_Rating': [96.5, 93.1, 89.4, 85.8, 104.5, 100.6, 99.8],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Red', 'Yellow', 'White', 'Red', 'Yellow'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [70.6, 68.1, 65.5, 61.2, 74.0, 70.3, 64.4],
#   'Slope_Rating': [119, 114, 107, 96, 126, 118, 106],
#   'Bogey_Rating': [92.7, 89.3, 85.3, 78.9, 103.6, 98.1, 89.3],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Regular', 'Forward'],
#   'Par': [70, 70],
#   'USGA_Rating': [68.4, 67.4],
#   'Slope_Rating': [110, 108],
#   'Bogey_Rating': [88.7, 87.4],
#   'Gender': ['M', 'M']},
#  {'Tee': ['Tips',
#    'Black',
#    'Gold',
#    'Blue',
#    'White',
#    'Red',
#    'Blue',
#    'White',
#    'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [76.1, 75.2, 72.7, 71.2, 68.7, 64.3, 78.1, 75.0, 69.6],
#   'Slope_Rating': [140, 138, 132, 129, 124, 105, 149, 139, 121],
#   'Bogey_Rating': [102.1, 100.8, 97.2, 95.2, 91.6, 83.8, 113.2, 107.8, 98.0],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Regular', 'Forward', 'Regular', 'Forward'],
#   'Par': [62, 60, 68, 66],
#   'USGA_Rating': [64.2, 61.2, 68.8, 64.4],
#   'Slope_Rating': [103, 91, 121, 114],
#   'Bogey_Rating': [83.4, 78.2, 97.4, 91.4],
#   'Gender': ['M', 'M', 'F', 'F']},
#  {'Tee': ['Gold/Professional',
#    'Players',
#    'Green/Champ',
#    'Green/White Combo',
#    'White/Back',
#    'Black/White',
#    'Black/Middle',
#    'White/Back',
#    'Black/White',
#    'Black/Middle',
#    'Black/Silver',
#    'Silver/Forward'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.3,
#    72.1,
#    70.7,
#    69.6,
#    68.6,
#    67.2,
#    65.6,
#    73.5,
#    71.3,
#    70.0,
#    68.6,
#    65.8],
#   'Slope_Rating': [141, 136, 133, 131, 127, 124, 120, 134, 126, 120, 114, 109],
#   'Bogey_Rating': [99.5,
#    97.3,
#    95.5,
#    94.0,
#    92.1,
#    90.1,
#    87.8,
#    105.0,
#    100.9,
#    98.2,
#    95.4,
#    91.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black', 'Gold', 'Blue', 'Tour', 'Red', 'Blue', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [71.6, 70.5, 69.6, 69.4, 68.3, 74.7, 73.1],
#   'Slope_Rating': [128, 125, 121, 120, 118, 136, 131],
#   'Bogey_Rating': [95.4, 93.7, 92.0, 91.7, 90.3, 106.8, 103.9],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Gold', 'Blue', 'Tour', 'Red', 'Blue', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 73, 72],
#   'USGA_Rating': [72.0, 69.3, 68.1, 67.5, 66.0, 73.2, 70.7],
#   'Slope_Rating': [123, 115, 111, 109, 106, 131, 121],
#   'Bogey_Rating': [94.7, 90.7, 88.7, 87.8, 85.7, 104.1, 99.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Rocks',
#    'Black',
#    'Blue',
#    'White',
#    'Green',
#    'Red',
#    'Gold',
#    'Cactus',
#    'White',
#    'Green',
#    'Red',
#    'Gold',
#    'Cactus'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 58, 72, 72, 72, 72, 64],
#   'USGA_Rating': [74.5,
#    72.2,
#    71.0,
#    69.6,
#    67.1,
#    65.8,
#    64.5,
#    59.5,
#    75.4,
#    72.7,
#    70.9,
#    69.3,
#    61.7],
#   'Slope_Rating': [144,
#    136,
#    134,
#    129,
#    121,
#    115,
#    112,
#    100,
#    139,
#    132,
#    123,
#    119,
#    105],
#   'Bogey_Rating': [101.3,
#    97.3,
#    95.8,
#    93.5,
#    89.6,
#    87.2,
#    85.2,
#    78.1,
#    108.1,
#    103.7,
#    99.9,
#    97.3,
#    86.4],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Rocks',
#    'Black',
#    'Blue',
#    'White',
#    'Green',
#    'Red',
#    'Cactus',
#    'White',
#    'Green',
#    'Red',
#    'Cactus'],
#   'Par': [72, 72, 72, 72, 72, 72, 58, 72, 72, 72, 64],
#   'USGA_Rating': [74.6,
#    72.4,
#    71.0,
#    69.4,
#    66.8,
#    65.6,
#    59.4,
#    76.0,
#    72.8,
#    70.5,
#    61.4],
#   'Slope_Rating': [140, 138, 136, 129, 123, 116, 101, 142, 128, 124, 104],
#   'Bogey_Rating': [100.5,
#    98.0,
#    96.1,
#    93.3,
#    89.6,
#    87.1,
#    78.2,
#    109.5,
#    102.8,
#    99.6,
#    85.9],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'Silver', 'Red', 'White', 'Red'],
#   'Par': [71, 71, 70, 69, 68, 71, 71],
#   'USGA_Rating': [70.8, 69.0, 67.3, 65.8, 64.6, 73.4, 69.4],
#   'Slope_Rating': [121, 117, 115, 112, 110, 123, 115],
#   'Bogey_Rating': [93.2, 90.7, 88.6, 86.5, 84.9, 102.0, 96.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Stronghold',
#    'Warrior',
#    'Apache',
#    'Chieftan',
#    'Maiden',
#    'Chieftan (white)',
#    'White/Red Combo 2015',
#    'Maiden (red)'],
#   'Par': [72, 72, 71, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.6, 72.4, 70.0, 67.9, 64.8, 73.7, 71.5, 70.2],
#   'Slope_Rating': [143, 136, 127, 120, 114, 132, 127, 120],
#   'Bogey_Rating': [101.1, 97.6, 93.5, 90.1, 85.9, 104.7, 101.3, 98.4],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White'],
#   'Par': [68, 68],
#   'USGA_Rating': [63.0, 61.4],
#   'Slope_Rating': [99, 96],
#   'Bogey_Rating': [81.4, 79.2],
#   'Gender': ['M', 'M']},
#  {'Tee': ['Blue', 'White', 'Gold', 'White', 'Red', 'Green'],
#   'Par': [71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [67.5, 65.9, 64.0, 71.9, 68.9, 62.6],
#   'Slope_Rating': [108, 104, 99, 118, 110, 95],
#   'Bogey_Rating': [87.6, 85.2, 82.3, 99.6, 94.8, 84.9],
#   'Gender': ['M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black', 'White', 'Gold', 'Orange', 'White', 'Gold', 'Orange'],
#   'Par': [71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [70.9, 67.6, 65.7, 64.7, 73.0, 70.3, 69.0],
#   'Slope_Rating': [120, 113, 110, 107, 122, 117, 113],
#   'Bogey_Rating': [93.1, 88.6, 86.0, 84.5, 101.7, 97.8, 95.7],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Champion', 'Regular', 'Senior', 'Forward', 'Regular', 'Forward'],
#   'Par': [71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [69.7, 67.2, 64.9, 62.7, 72.7, 67.1],
#   'Slope_Rating': [124, 116, 111, 100, 129, 112],
#   'Bogey_Rating': [92.8, 88.6, 85.5, 81.2, 102.9, 93.5],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Back', 'Middle', 'Front', 'Gold', 'Front', 'Gold'],
#   'Par': [73, 71, 70, 68, 0, 0],
#   'USGA_Rating': [72.0, 70.1, 67.8, 63.9, 73.2, 68.2],
#   'Slope_Rating': [116, 114, 111, 100, 120, 109],
#   'Bogey_Rating': [93.5, 91.2, 88.3, 82.5, 101.5, 93.9],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue',
#    'Blue/White',
#    'White',
#    'White/Green',
#    'Green',
#    'Red',
#    'Junior',
#    'White',
#    'Green',
#    'Combo',
#    'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [71.9,
#    71.2,
#    69.9,
#    69.0,
#    67.9,
#    65.7,
#    55.6,
#    75.9,
#    74.2,
#    71.8,
#    70.6],
#   'Slope_Rating': [130, 128, 124, 122, 120, 115, 91, 137, 127, 124, 120],
#   'Bogey_Rating': [96.0,
#    95.0,
#    93.0,
#    91.6,
#    90.2,
#    87.0,
#    72.4,
#    108.2,
#    104.1,
#    100.9,
#    98.9],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Yellow', 'Red', 'White', 'Yellow', 'Red'],
#   'Par': [72, 72, 72, 72, 73, 73, 73],
#   'USGA_Rating': [70.8, 69.0, 66.6, 64.2, 74.4, 71.6, 68.4],
#   'Slope_Rating': [120, 116, 112, 107, 123, 117, 112],
#   'Bogey_Rating': [93.1, 90.5, 87.3, 84.1, 103.2, 99.2, 94.9],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'Players',
#    'White',
#    'Turquoise',
#    'Copper',
#    'White',
#    'Turquoise',
#    'Mixed',
#    'Copper'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.4, 71.1, 70.8, 69.6, 67.2, 66.2, 76.5, 73.8, 72.1, 70.9],
#   'Slope_Rating': [126, 124, 123, 121, 117, 114, 134, 129, 127, 125],
#   'Bogey_Rating': [96.7,
#    94.0,
#    93.5,
#    92.0,
#    88.9,
#    87.4,
#    108.0,
#    104.0,
#    101.9,
#    100.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Black/Blue',
#    'Blue',
#    'Blue/White',
#    'White',
#    'White/Gold',
#    'Gold',
#    'Gold/Green',
#    'Green',
#    'Blue',
#    'Blue/White',
#    'White',
#    'White/Gold',
#    'Gold',
#    'Gold/Green',
#    'Green'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [71.9,
#    71.0,
#    70.0,
#    68.6,
#    67.0,
#    65.7,
#    64.6,
#    62.7,
#    61.2,
#    75.5,
#    73.4,
#    71.9,
#    70.4,
#    69.2,
#    66.2,
#    63.6],
#   'Slope_Rating': [132,
#    128,
#    125,
#    123,
#    121,
#    117,
#    114,
#    108,
#    103,
#    137,
#    133,
#    130,
#    126,
#    125,
#    119,
#    113],
#   'Bogey_Rating': [96.4,
#    94.8,
#    93.2,
#    91.4,
#    89.4,
#    87.4,
#    85.8,
#    82.7,
#    80.4,
#    107.8,
#    104.8,
#    102.5,
#    100.1,
#    98.7,
#    94.2,
#    90.2],
#   'Gender': ['M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'F',
#    'F',
#    'F',
#    'F',
#    'F',
#    'F',
#    'F']},
#  {'Tee': ['Gold', 'White', 'Gold', 'White', 'Purple'],
#   'Par': [61, 61, 61, 61, 61],
#   'USGA_Rating': [58.7, 56.6, 59.8, 56.9, 53.8],
#   'Slope_Rating': [90, 81, 98, 89, 78],
#   'Bogey_Rating': [75.4, 71.6, 82.8, 77.8, 72.2],
#   'Gender': ['M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Gold', 'Blue', 'White', 'Red', 'White', 'Red/White Combo', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [71.3, 69.2, 67.0, 62.3, 73.2, 69.9, 67.2],
#   'Slope_Rating': [120, 114, 109, 94, 123, 117, 106],
#   'Bogey_Rating': [93.5, 90.3, 87.2, 79.7, 102.1, 97.5, 92.2],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'Red', 'Blue', 'Red'],
#   'Par': [59, 58, 59, 59],
#   'USGA_Rating': [57.2, 54.0, 59.1, 55.8],
#   'Slope_Rating': [82, 72, 86, 81],
#   'Bogey_Rating': [72.3, 67.3, 79.4, 74.7],
#   'Gender': ['M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'White', 'Red'],
#   'Par': [59, 59, 59, 59],
#   'USGA_Rating': [57.6, 56.9, 57.7, 56.9],
#   'Slope_Rating': [88, 85, 88, 86],
#   'Bogey_Rating': [74.0, 72.7, 78.0, 77.3],
#   'Gender': ['M', 'M', 'F', 'F']},
#  {'Tee': ['Green', 'White', 'Black', 'Red', 'Red'],
#   'Par': [71, 71, 69, 66, 69],
#   'USGA_Rating': [69.3, 67.7, 65.9, 63.8, 68.6],
#   'Slope_Rating': [120, 116, 114, 109, 125],
#   'Bogey_Rating': [91.6, 89.1, 87.0, 84.1, 98.1],
#   'Gender': ['M', 'M', 'M', 'M', 'F']},
#  {'Tee': ['Black',
#    'Black/Blue',
#    'Blue',
#    'Blue/White',
#    'White',
#    'White/Red',
#    'Red',
#    'Blue',
#    'White/Blue',
#    'White',
#    'Red/White Combo',
#    'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.2,
#    71.0,
#    69.6,
#    68.0,
#    65.9,
#    63.6,
#    62.3,
#    75.7,
#    73.8,
#    71.1,
#    69.1,
#    68.1],
#   'Slope_Rating': [138, 133, 129, 124, 118, 111, 106, 140, 136, 131, 120, 107],
#   'Bogey_Rating': [98.7,
#    95.7,
#    93.6,
#    90.9,
#    87.8,
#    84.1,
#    82.0,
#    108.8,
#    105.9,
#    101.9,
#    97.3,
#    93.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Verde',
#    'Verde/Camel',
#    'Camel',
#    'Camel/Teal',
#    'Teal',
#    'Teal/Red',
#    'Red',
#    'Camel',
#    'Camel/Teal',
#    'Teal',
#    'Teal/Red',
#    'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.2,
#    71.9,
#    70.4,
#    69.1,
#    67.6,
#    66.4,
#    64.8,
#    63.8,
#    75.2,
#    73.2,
#    71.9,
#    69.8,
#    68.5],
#   'Slope_Rating': [138,
#    132,
#    128,
#    125,
#    121,
#    118,
#    114,
#    111,
#    135,
#    132,
#    130,
#    123,
#    119],
#   'Bogey_Rating': [99.8,
#    96.4,
#    94.2,
#    92.3,
#    90.0,
#    88.3,
#    85.9,
#    84.4,
#    106.9,
#    104.3,
#    102.4,
#    98.8,
#    96.6],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Black/White',
#    'White',
#    'White/Yellow',
#    'Yellow',
#    'Yellow/Orange',
#    'Orange',
#    'Black',
#    'Black/White',
#    'White',
#    'Yellow',
#    'Yellow/Orange',
#    'Orange'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [72.2,
#    71.0,
#    70.0,
#    69.1,
#    67.7,
#    65.5,
#    64.1,
#    78.9,
#    77.6,
#    76.4,
#    74.4,
#    71.2,
#    68.6],
#   'Slope_Rating': [130,
#    126,
#    123,
#    121,
#    119,
#    114,
#    111,
#    143,
#    139,
#    137,
#    133,
#    127,
#    121],
#   'Bogey_Rating': [96.4,
#    94.4,
#    92.8,
#    91.5,
#    89.8,
#    86.6,
#    84.6,
#    112.5,
#    110.4,
#    108.7,
#    105.8,
#    101.0,
#    97.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Oro',
#    'Azul',
#    'Verde',
#    'Blanco',
#    'Blanco/Rojo',
#    'Rojo',
#    'Azul',
#    'Verde',
#    'Blanco',
#    'Rojo/Blanco Combo',
#    'Rojo'],
#   'Par': [70, 70, 70, 70, 69, 69, 70, 70, 70, 70, 70],
#   'USGA_Rating': [71.6,
#    68.6,
#    66.6,
#    64.2,
#    61.9,
#    61.3,
#    73.9,
#    72.2,
#    68.5,
#    66.5,
#    64.8],
#   'Slope_Rating': [138, 131, 124, 114, 106, 106, 142, 135, 123, 116, 115],
#   'Bogey_Rating': [97.2,
#    92.9,
#    89.5,
#    85.4,
#    81.6,
#    81.0,
#    107.2,
#    104.1,
#    97.5,
#    93.8,
#    91.8],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Black/Blue',
#    'Blue',
#    'Blue/White',
#    'White',
#    'White/Gray',
#    'Gray',
#    'Teal',
#    'White',
#    'Gray',
#    'Gray/Teal',
#    'Teal'],
#   'Par': [71, 71, 71, 71, 71, 71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [71.6,
#    70.3,
#    69.1,
#    68.0,
#    67.1,
#    65.1,
#    64.4,
#    63.0,
#    72.2,
#    68.7,
#    67.4,
#    66.2],
#   'Slope_Rating': [139, 137, 134, 131, 127, 120, 116, 109, 146, 135, 129, 125],
#   'Bogey_Rating': [97.3,
#    95.6,
#    93.9,
#    92.3,
#    90.7,
#    87.3,
#    86.0,
#    83.2,
#    106.7,
#    100.4,
#    97.8,
#    95.6],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Championship', 'Regular', 'Combo', 'Red', 'Regular', 'Red'],
#   'Par': [72, 72, 70, 70, 72, 72],
#   'USGA_Rating': [71.5, 69.0, 67.6, 65.9, 75.4, 71.6],
#   'Slope_Rating': [125, 116, 112, 107, 129, 121],
#   'Bogey_Rating': [94.6, 90.5, 88.4, 85.8, 105.7, 100.2],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Gold', 'Silver', 'Copper', 'Silver', 'Copper'],
#   'Par': [72, 70, 69, 66, 72, 70],
#   'USGA_Rating': [71.9, 69.6, 67.2, 63.8, 71.8, 68.1],
#   'Slope_Rating': [128, 125, 118, 114, 132, 120],
#   'Bogey_Rating': [95.7, 92.8, 89.2, 85.0, 102.8, 96.4],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue/Blue', 'Blue/Red', 'Red/Red', 'Blue'],
#   'Par': [64, 64, 64, 64],
#   'USGA_Rating': [61.2, 61.0, 60.8, 65.2],
#   'Slope_Rating': [101, 100, 99, 103],
#   'Bogey_Rating': [80.0, 79.6, 79.2, 89.4],
#   'Gender': ['M', 'M', 'M', 'F']},
#  {'Tee': ['Graham',
#    'Panks',
#    '1 Pine',
#    '1 Pine/2 Pine',
#    '2 Pine',
#    '2 Pine/3 Pine',
#    '3 Pine',
#    '3 Pines Combo',
#    '2 Pines',
#    'Mixed',
#    '3 Pines',
#    'green/red 3 Pines combo',
#    '4 Pines'],
#   'Par': [73, 72, 70, 69, 68, 68, 66, 65, 69, 66, 69, 66, 58],
#   'USGA_Rating': [73.0,
#    71.8,
#    70.4,
#    68.9,
#    68.2,
#    66.1,
#    64.8,
#    61.0,
#    73.3,
#    70.8,
#    69.5,
#    63.9,
#    57.0],
#   'Slope_Rating': [139,
#    136,
#    130,
#    125,
#    121,
#    116,
#    113,
#    108,
#    144,
#    133,
#    124,
#    116,
#    92],
#   'Bogey_Rating': [98.7,
#    97.0,
#    94.5,
#    92.1,
#    90.6,
#    87.7,
#    85.8,
#    81.0,
#    107.3,
#    102.1,
#    98.7,
#    91.2,
# ...
#   'USGA_Rating': [70.5, 70.3, 69.7, 69.0, 67.4, 60.6, 75.0, 72.9, 64.5],
#   'Slope_Rating': [125, 125, 123, 121, 116, 102, 133, 129, 111],
#   'Bogey_Rating': [93.7, 93.4, 92.6, 91.5, 89.0, 79.5, 106.3, 103.3, 90.7],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'White', 'Gold'],
#   'Par': [71, 69, 68, 71, 71],
#   'USGA_Rating': [68.0, 66.4, 65.3, 71.4, 69.9],
#   'Slope_Rating': [116, 112, 111, 126, 124],
#   'Bogey_Rating': [89.6, 87.2, 85.8, 101.1, 99.0],
#   'Gender': ['M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black',
#    'White',
#    'Yellow',
#    'Red',
#    'BLACK',
#    'WHITE',
#    'Yellow',
#    'RED'],
#   'Par': [0, 0, 0, 0, 0, 0, 0, 0],
#   'USGA_Rating': [69.7, 68.3, 66.4, 65.0, 75.5, 73.4, 71.0, 68.6],
#   'Slope_Rating': [128, 123, 114, 105, 131, 127, 121, 117],
#   'Bogey_Rating': [93.4, 91.0, 87.6, 84.5, 106.3, 103.3, 99.6, 96.1],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Gold',
#    'Blue',
#    'Blue/White Combo',
#    'White',
#    'Green',
#    'WHITE',
#    'RED'],
#   'Par': [72, 72, 72, 72, 68, 72, 72],
#   'USGA_Rating': [73.8, 71.7, 70.2, 69.3, 65.7, 74.9, 70.7],
#   'Slope_Rating': [133, 129, 128, 127, 122, 125, 117],
#   'Bogey_Rating': [98.8, 95.8, 94.8, 93.6, 88.9, 104.3, 98.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'Silver',
#    'White',
#    'Senior Combo',
#    'Green',
#    'Blue',
#    'Silver',
#    'White',
#    'Green'],
#   'Par': [72, 72, 72, 72, 72, 68, 73, 72, 72, 71],
#   'USGA_Rating': [72.0, 70.8, 69.7, 68.9, 67.7, 65.5, 77.1, 75.5, 73.8, 70.1],
#   'Slope_Rating': [127, 125, 124, 122, 119, 116, 133, 130, 126, 120],
#   'Bogey_Rating': [95.4,
#    93.9,
#    92.6,
#    91.4,
#    89.8,
#    87.0,
#    108.5,
#    106.2,
#    103.5,
#    98.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Silver', 'Black', 'Blue', 'White', 'WHITE', 'SAND'],
#   'Par': [72, 72, 72, 69, 72, 72],
#   'USGA_Rating': [74.6, 72.4, 70.1, 67.5, 72.8, 70.4],
#   'Slope_Rating': [125, 121, 116, 111, 122, 114],
#   'Bogey_Rating': [97.8, 94.8, 91.6, 88.1, 101.5, 97.2],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Red', 'White', 'Gold', 'Red'],
#   'Par': [72, 72, 71, 70, 73, 72, 72],
#   'USGA_Rating': [73.1, 70.7, 69.1, 67.1, 76.2, 74.1, 72.1],
#   'Slope_Rating': [130, 125, 119, 117, 133, 126, 120],
#   'Bogey_Rating': [97.2, 93.9, 91.2, 89.3, 107.5, 103.8, 100.3],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['White/Gold', 'Red/Green', 'Red/Green'],
#   'Par': [64, 64, 64],
#   'USGA_Rating': [61.2, 58.5, 61.8],
#   'Slope_Rating': [101, 96, 103],
#   'Bogey_Rating': [79.9, 76.2, 86.0],
#   'Gender': ['M', 'M', 'F']},
#  {'Tee': ['Blue',
#    'Blue/White',
#    'White',
#    'Gold',
#    'Gold/Red',
#    'Red',
#    'Blue',
#    'Blue/White',
#    'White',
#    'Gold',
#    'Gold/Red',
#    'Red'],
#   'Par': [71, 71, 71, 71, 71, 71, 71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [70.9,
#    70.0,
#    69.3,
#    67.3,
#    65.6,
#    64.6,
#    76.8,
#    75.8,
#    74.9,
#    72.8,
#    70.8,
#    69.6],
#   'Slope_Rating': [125, 123, 121, 116, 112, 109, 136, 134, 132, 128, 124, 121],
#   'Bogey_Rating': [94.0,
#    92.7,
#    91.7,
#    88.9,
#    86.4,
#    84.9,
#    108.8,
#    107.4,
#    106.0,
#    102.9,
#    100.0,
#    98.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue',
#    'Gold',
#    'White',
#    'White/Green Combo',
#    'Green',
#    'WHITE',
#    'White/Green Combo',
#    'GREEN-LONG',
#    'GREEN-SHORT'],
#   'Par': [72, 72, 71, 70, 69, 72, 72, 72, 72],
#   'USGA_Rating': [73.5, 71.4, 69.7, 68.4, 66.4, 75.9, 74.2, 72.3, 72.0],
#   'Slope_Rating': [129, 126, 124, 122, 120, 133, 129, 124, 124],
#   'Bogey_Rating': [97.6, 94.8, 92.7, 91.1, 88.7, 107.2, 104.6, 101.6, 101.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Gold', 'Blue', 'White', 'Red', 'White', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.3, 71.1, 69.6, 67.0, 75.8, 73.8],
#   'Slope_Rating': [127, 122, 118, 115, 131, 128],
#   'Bogey_Rating': [96.8, 93.7, 91.5, 88.3, 106.7, 103.9],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'Blue/White',
#    'White',
#    'Yellow',
#    'Red',
#    'WHITE',
#    'YELLOW',
#    'YELLOW/RED',
#    'RED'],
#   'Par': [72, 72, 72, 72, 70, 70, 72, 72, 72, 72],
#   'USGA_Rating': [70.2, 69.4, 68.7, 68.0, 66.0, 64.8, 73.2, 70.8, 70.0, 69.3],
#   'Slope_Rating': [130, 128, 127, 125, 119, 115, 124, 124, 124, 123],
#   'Bogey_Rating': [94.4,
#    93.2,
#    92.2,
#    91.2,
#    88.2,
#    86.2,
#    102.4,
#    100.0,
#    99.1,
#    98.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['B9 Twice - Blue',
#    'Blue',
#    'B9 Twice - White/Blue',
#    'White',
#    'B9 Twice - White',
#    'Red',
#    'Red (Gold #9)',
#    'Gold'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.8, 73.6, 72.3, 70.9, 70.8, 72.8, 72.2, 69.9],
#   'Slope_Rating': [137, 135, 135, 132, 133, 129, 126, 119],
#   'Bogey_Rating': [99.8, 98.7, 97.3, 95.4, 95.0, 103.1, 101.9, 97.9],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White'],
#   'Par': [62, 62],
#   'USGA_Rating': [59.4, 58.6],
#   'Slope_Rating': [98, 96],
#   'Bogey_Rating': [77.6, 76.4],
#   'Gender': ['M', 'M']},
#  {'Tee': ['Black', 'Blue', 'White', 'Red', 'Blue', 'White', 'Red'],
#   'Par': [71, 71, 68, 66, 71, 71, 71],
#   'USGA_Rating': [70.9, 68.8, 66.0, 62.9, 74.0, 70.5, 66.9],
#   'Slope_Rating': [125, 123, 112, 107, 130, 123, 112],
#   'Bogey_Rating': [94.0, 91.5, 86.1, 82.4, 104.5, 99.3, 93.3],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'White',
#    'White/Gold',
#    'Gold',
#    'Gold/Red',
#    'Red',
#    'BLUE',
#    'WHITE',
#    'WHITE/GOLD COMBO',
#    'GOLD',
#    'RED/GOLD COMBO',
#    'RED'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.0,
#    72.5,
#    70.3,
#    68.8,
#    67.3,
#    66.1,
#    65.0,
#    79.9,
#    77.2,
#    75.4,
#    73.7,
#    72.3,
#    70.8],
#   'Slope_Rating': [134,
#    130,
#    126,
#    122,
#    119,
#    114,
#    110,
#    138,
#    132,
#    128,
#    124,
#    121,
#    117],
#   'Bogey_Rating': [98.9,
#    96.7,
#    93.7,
#    91.5,
#    89.3,
#    87.3,
#    85.4,
#    112.3,
#    108.2,
#    105.5,
#    102.9,
#    100.7,
#    98.4],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue',
#    'White',
#    'White/Gold',
#    'Gold',
#    'Gold/Red',
#    'Red',
#    'Blue',
#    'White',
#    'Gold',
#    'Gold/Red',
#    'Red',
#    'Orange'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [72.7,
#    70.6,
#    69.4,
#    68.3,
#    66.3,
#    65.2,
#    79.9,
#    77.1,
#    74.7,
#    72.5,
#    71.3,
#    65.8],
#   'Slope_Rating': [129, 124, 121, 118, 114, 110, 143, 139, 135, 132, 130, 110],
#   'Bogey_Rating': [96.5,
#    93.6,
#    91.8,
#    90.1,
#    87.4,
#    85.6,
#    114.1,
#    109.9,
#    106.4,
#    103.7,
#    101.9,
#    91.7],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue/White', 'BLUE/WHITE', 'WHITE/RED'],
#   'Par': [64, 64, 64],
#   'USGA_Rating': [61.7, 64.3, 62.6],
#   'Slope_Rating': [101, 105, 105],
#   'Bogey_Rating': [80.6, 89.0, 87.4],
#   'Gender': ['M', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Blue', 'White', 'Red', 'Red Fr 9 X2'],
#   'Par': [70, 70, 70, 70, 70, 68],
#   'USGA_Rating': [68.4, 66.9, 73.2, 71.5, 67.9, 67.8],
#   'Slope_Rating': [120, 118, 129, 125, 120, 121],
#   'Bogey_Rating': [90.7, 88.8, 103.6, 101.0, 96.2, 96.4],
#   'Gender': ['M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Red'],
#   'Par': [58, 58, 60],
#   'USGA_Rating': [59.6, 59.0, 60.4],
#   'Slope_Rating': [96, 94, 95],
#   'Bogey_Rating': [77.4, 76.4, 82.8],
#   'Gender': ['M', 'M', 'F']},
#  {'Tee': ['Blue',
#    'White',
#    'Gold',
#    'Red',
#    'White',
#    'Gold',
#    'Red (Front 9 - Twice)',
#    'Red',
#    'Red (Back 9 - Twice)'],
#   'Par': [71, 71, 71, 71, 71, 71, 72, 71, 70],
#   'USGA_Rating': [70.4, 69.1, 66.8, 65.3, 75.4, 72.1, 71.4, 70.7, 70.0],
#   'Slope_Rating': [116, 113, 108, 105, 125, 122, 121, 119, 117],
#   'Bogey_Rating': [92.0, 90.1, 86.8, 84.8, 104.8, 100.9, 100.0, 98.8, 97.6],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'Blue/White Combo',
#    'White',
#    'Orange',
#    'Green',
#    'Yellow',
#    'Blue',
#    'Blue/White combo',
#    'White',
#    'Orange',
#    'Green',
#    'Yellow'],
#   'Par': [72, 72, 71, 70, 68, 68, 64, 72, 72, 72, 72, 71, 68],
#   'USGA_Rating': [71.3,
#    70.1,
#    68.2,
#    67.0,
#    65.4,
#    64.3,
#    61.5,
#    75.9,
#    74.2,
#    72.9,
#    70.7,
#    68.8,
#    64.5],
#   'Slope_Rating': [129,
#    126,
#    123,
#    120,
#    114,
#    107,
#    97,
#    131,
#    126,
#    124,
#    119,
#    115,
#    106],
#   'Bogey_Rating': [95.3,
#    93.6,
#    91.2,
#    89.3,
#    86.6,
#    84.1,
#    79.4,
#    106.7,
#    103.9,
#    102.2,
#    98.7,
#    96.0,
#    89.5],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'White',
#    'Green',
#    'Gold',
#    'Green',
#    'Combo',
#    'Gold',
#    'Forward'],
#   'Par': [71, 71, 71, 71, 71, 74, 74, 74, 74],
#   'USGA_Rating': [75.6, 74.6, 72.2, 70.7, 70.0, 76.8, 75.1, 74.4, 72.1],
#   'Slope_Rating': [137, 135, 130, 126, 124, 143, 138, 136, 132],
#   'Bogey_Rating': [101.0, 99.6, 96.4, 94.1, 93.0, 110.4, 107.6, 106.4, 103.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue',
#    'Blue/White',
#    'White',
#    'Yellow',
#    'Blue',
#    'Blue/White',
#    'White',
#    'Yellow/White',
#    'Yellow'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [69.8, 69.2, 68.6, 64.0, 76.7, 76.0, 75.3, 72.2, 69.0],
#   'Slope_Rating': [117, 116, 114, 102, 131, 130, 129, 122, 116],
#   'Bogey_Rating': [91.6, 90.7, 89.8, 83.0, 107.7, 106.7, 105.7, 101.0, 96.4],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Tournament',
#    'Club',
#    'Challenge',
#    'Olive',
#    'TOURNAMENT',
#    'Club',
#    'CHALLENGE',
#    'OLIVE'],
#   'Par': [72, 72, 71, 69, 75, 72, 72, 72],
#   'USGA_Rating': [72.6, 71.4, 69.4, 65.2, 79.0, 77.5, 75.5, 70.9],
#   'Slope_Rating': [126, 125, 123, 112, 139, 137, 131, 123],
#   'Bogey_Rating': [96.0, 94.6, 92.1, 85.9, 111.8, 109.8, 106.3, 99.9],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Platinum',
#    'Copper',
#    'Black',
#    'Silver',
#    'Bronze',
#    'Black',
#    'Silver',
#    'Bronze'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.8, 71.6, 69.1, 66.2, 63.1, 75.1, 71.3, 67.1],
#   'Slope_Rating': [135, 130, 125, 117, 107, 131, 123, 116],
#   'Bogey_Rating': [98.8, 95.7, 92.2, 87.9, 82.9, 105.9, 100.1, 94.3],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Tournament',
#    'Championship',
#    'Combo',
#    'Regular',
#    'White/Red Combo',
#    'Red',
#    'WHITE',
#    'RED/WHITE',
#    'RED'],
#   'Par': [72, 72, 72, 72, 72, 68, 72, 71, 71],
#   'USGA_Rating': [74.2, 71.7, 70.5, 69.1, 67.3, 65.6, 73.7, 71.7, 69.4],
#   'Slope_Rating': [135, 129, 127, 118, 115, 114, 129, 121, 117],
#   'Bogey_Rating': [99.3, 95.7, 94.1, 91.1, 88.7, 86.9, 103.9, 100.1, 97.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Red', 'Gold', 'Blue', 'White', 'Red', 'Gold'],
#   'Par': [72, 70, 68, 62, 72, 72, 72, 70],
#   'USGA_Rating': [67.4, 66.8, 65.2, 61.2, 72.6, 71.6, 69.8, 64.2],
#   'Slope_Rating': [117, 111, 106, 96, 124, 122, 118, 106],
#   'Bogey_Rating': [89.2, 87.4, 84.8, 79.0, 101.8, 100.6, 97.8, 89.2],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue',
#    'White',
#    'White/Red Combo',
#    'Red',
#    'Red/Gold Combo',
#    'Gold',
#    'White',
#    'White/Red Combo',
#    'Red',
#    'Red/Gold Combo',
#    'Gold'],
#   'Par': [72, 72, 69, 69, 67, 66, 72, 72, 72, 69, 69],
#   'USGA_Rating': [70.0,
#    68.7,
#    67.2,
#    66.8,
#    64.6,
#    64.2,
#    73.6,
#    71.7,
#    71.1,
#    68.9,
#    67.9],
#   'Slope_Rating': [123, 121, 115, 114, 109, 106, 130, 125, 124, 118, 115],
#   'Bogey_Rating': [92.9,
#    91.2,
#    88.6,
#    88.0,
#    84.7,
#    83.9,
#    104.3,
#    101.3,
#    100.4,
#    96.8,
#    95.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Tournament - Long',
#    'Tournament',
#    'Blue',
#    'Blue/Silver Combo',
#    'Silver',
#    'Silver/Gold Combo',
#    'Gold',
#    'Blue',
#    'Silver',
#    'Silver/Gold combo',
#    'Gold long',
#    'Gold short'],
#   'Par': [72, 72, 72, 72, 72, 69, 68, 68, 74, 72, 71, 73, 73],
#   'USGA_Rating': [72.3,
#    71.7,
#    71.4,
#    70.8,
#    69.6,
#    68.8,
#    67.1,
#    66.0,
#    77.3,
#    75.2,
#    73.2,
#    71.6,
#    71.4],
#   'Slope_Rating': [140,
#    139,
#    137,
#    136,
#    133,
#    130,
#    124,
#    116,
#    141,
#    136,
#    133,
#    132,
#    131],
#   'Bogey_Rating': [98.3,
#    97.6,
#    97.0,
#    96.2,
#    94.3,
#    92.9,
#    90.2,
#    87.5,
#    110.7,
#    107.3,
#    104.5,
#    102.7,
#    102.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Red', 'Blue', 'White', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [70.5, 68.9, 66.3, 76.5, 74.7, 71.7],
#   'Slope_Rating': [126, 122, 116, 135, 130, 124],
#   'Bogey_Rating': [93.9, 91.4, 87.8, 108.4, 105.4, 100.8],
#   'Gender': ['M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Red', 'Blue', 'White', 'Red'],
#   'Par': [71, 71, 71, 71, 71, 71],
#   'USGA_Rating': [69.0, 67.5, 65.3, 74.7, 73.1, 70.5],
#   'Slope_Rating': [124, 120, 115, 135, 129, 124],
#   'Bogey_Rating': [91.9, 89.7, 86.6, 106.4, 103.6, 99.7],
#   'Gender': ['M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Red', 'Blue', 'White', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [69.5, 68.0, 66.4, 75.1, 73.4, 71.6],
#   'Slope_Rating': [125, 121, 116, 131, 127, 123],
#   'Bogey_Rating': [92.6, 90.5, 88.0, 105.9, 103.4, 100.5],
#   'Gender': ['M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Nicklaus',
#    'Black/Blue Combo',
#    'Champion',
#    'Combo',
#    'Member',
#    'Senior Combo',
#    'Senior',
#    'Gold',
#    'Gold/Red Combo',
#    'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 71, 72, 72, 72],
#   'USGA_Rating': [75.8, 74.6, 73.9, 72.6, 71.8, 69.9, 68.6, 74.6, 72.2, 70.8],
#   'Slope_Rating': [137, 136, 134, 131, 130, 128, 123, 134, 128, 125],
#   'Bogey_Rating': [101.3,
#    99.9,
#    98.8,
#    97.1,
#    96.0,
#    93.7,
#    91.5,
#    106.2,
#    102.3,
#    100.2],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black', 'Blue', 'Hanse', 'White', 'Red', 'White', 'Red'],
#   'Par': [72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [73.9, 72.0, 71.1, 69.3, 65.7, 74.7, 70.5],
#   'Slope_Rating': [135, 130, 128, 124, 114, 129, 120],
#   'Bogey_Rating': [98.9, 96.1, 94.8, 92.2, 86.8, 104.9, 98.7],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F']},
#  {'Tee': ['Black', 'Blue', 'White', 'Gold', 'Red', 'White', 'Gold', 'Red'],
#   'Par': [72, 72, 72, 70, 68, 72, 72, 71],
#   'USGA_Rating': [71.9, 70.7, 69.4, 65.4, 64.1, 75.4, 70.9, 69.2],
#   'Slope_Rating': [119, 118, 116, 109, 102, 126, 118, 114],
#   'Bogey_Rating': [94.1, 92.7, 91.0, 85.6, 83.1, 105.1, 98.7, 96.1],
#   'Gender': ['M', 'M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Blue', 'White', 'Gold', 'Silver', 'White', 'Gold', 'Silver'],
#   'Par': [72, 72, 72, 72, 73, 73, 73],
#   'USGA_Rating': [70.8, 69.1, 67.4, 60.9, 75.4, 73.6, 64.9],
#   'Slope_Rating': [125, 121, 117, 101, 128, 125, 106],
#   'Bogey_Rating': [94.0, 91.5, 89.1, 79.6, 105.5, 103.1, 89.8],
#   'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']},
#  {'Tee': ['Black',
#    'Blue',
#    'White',
#    'Silver',
#    'White/Silver/Red Combo',
#    'Red',
#    'Green',
#    'Gold',
#    'Blue',
#    'White',
#    'Silver',
#    'Red',
#    'Green',
#    'Gold'],
#   'Par': [72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72],
#   'USGA_Rating': [74.5,
#    72.8,
#    71.1,
#    69.5,
#    68.8,
#    67.8,
#    66.5,
#    64.4,
#    78.6,
#    77.1,
#    75.0,
#    72.8,
#    71.3,
#    69.1],
#   'Slope_Rating': [135,
#    131,
#    128,
#    125,
#    123,
#    121,
#    118,
#    113,
#    142,
#    138,
#    133,
#    130,
#    126,
#    121],
#   'Bogey_Rating': [99.6,
#    97.1,
#    94.8,
#    92.7,
#    91.6,
#    90.2,
#    88.5,
#    85.4,
#    112.1,
#    109.6,
#    106.3,
#    103.5,
#    100.9,
#    97.6],
#   'Gender': ['M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'M',
#    'F',
#    'F',
#    'F',
#    'F',
#    'F',
#    'F']},
#  ...]
